# %% [markdown]
# # Superstore Dataset
#
# ### Dataset Information
#
# 1. Order Details: Order ID, Order Date, Ship Date
# 2. Customer Details: Customer Name, Customer Segment
# 3. Product Details: Category, Sub-Category, Product Name
# 4. Sales Data: Sales Amount, Profit, Discount, Quantity
# 5. Geography: Region, State

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

import datetime as dt


import sys 
import warnings
if not sys.warnoptions: 
    warnings.simplefilter('ignore')

pd.set_option('display.max_columns', None)  
pd.set_option('display.max_rows', None)

import os
os.chdir(r"D:\OneDrive\Documents\Course\Imarticus Learning\Power BI\W Beyond\Assignment")

# %%
df_superstore=pd.read_excel('Superstore_Sales_Dataset (1).xlsx')
df_superstore.head()
# Out:
#   Order ID Order Date  Ship Date Customer Name Customer Segment  \
# 0  ORD1000 2023-03-28 2023-03-30   Customer 86      Home Office
# 1  ORD1001 2023-10-15 2023-10-17  Customer 449      Home Office
# 2  ORD1002 2023-01-24 2023-01-30   Customer 90        Corporate
# 3  ORD1003 2023-04-04 2023-04-09  Customer 383      Home Office
# 4  ORD1004 2023-06-11 2023-06-15   Customer 84   Small Business
#
#           Category Sub-Category Product Name  Sales Amount  Profit  Discount  \
# 0  Office Supplies      Binders   Binders 96        611.31   39.71      0.16
# 1       Technology       Phones    Phones 54         62.75    5.02      0.11
# 2       Technology     Printers  Printers 47        454.63   52.64      0.18
# 3       Technology     Printers  Printers 92        404.49  108.25      0.06
# 4  Office Supplies        Paper     Paper 43        295.64   50.94      0.05
#
#    Quantity Region       State
# 0         8  South       Texas
# 1         4   East  California
# ...

# %%
df_superstore.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Customer Name',
#        'Customer Segment', 'Category', 'Sub-Category', 'Product Name',
#        'Sales Amount', 'Profit', 'Discount', 'Quantity', 'Region', 'State'],
#       dtype='object')

# %%
df_superstore.shape
# Out:
# (1000, 14)

# %%
df_superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          1000 non-null   object
#  1   Order Date        1000 non-null   datetime64[ns]
#  2   Ship Date         1000 non-null   datetime64[ns]
#  3   Customer Name     1000 non-null   object
#  4   Customer Segment  1000 non-null   object
#  5   Category          1000 non-null   object
#  6   Sub-Category      1000 non-null   object
#  7   Product Name      1000 non-null   object
#  8   Sales Amount      1000 non-null   float64
#  9   Profit            1000 non-null   float64
#  10  Discount          1000 non-null   float64
#  11  Quantity          1000 non-null   int64
#  12  Region            1000 non-null   object
#  13  State             1000 non-null   object
# dtypes: datetime64[ns](2), float64(3), int64(1), object(8)
# memory usage: 109.5+ KB

# %%
#unique values

cols=df_superstore.columns

for i in cols:
    print(f'The number of unique values in {i} are: {df_superstore[i].nunique()}. \n')
    print(f'The unique values in {i} are: {df_superstore[i].unique()}. \n\n')
# Out:
# The number of unique values in Order ID are: 1000.
#
# The unique values in Order ID are: ['ORD1000' 'ORD1001' 'ORD1002' 'ORD1003' 'ORD1004' 'ORD1005' 'ORD1006'
#  'ORD1007' 'ORD1008' 'ORD1009' 'ORD1010' 'ORD1011' 'ORD1012' 'ORD1013'
#  'ORD1014' 'ORD1015' 'ORD1016' 'ORD1017' 'ORD1018' 'ORD1019' 'ORD1020'
#  'ORD1021' 'ORD1022' 'ORD1023' 'ORD1024' 'ORD1025' 'ORD1026' 'ORD1027'
#  'ORD1028' 'ORD1029' 'ORD1030' 'ORD1031' 'ORD1032' 'ORD1033' 'ORD1034'
#  'ORD1035' 'ORD1036' 'ORD1037' 'ORD1038' 'ORD1039' 'ORD1040' 'ORD1041'
#  'ORD1042' 'ORD1043' 'ORD1044' 'ORD1045' 'ORD1046' 'ORD1047' 'ORD1048'
#  'ORD1049' 'ORD1050' 'ORD1051' 'ORD1052' 'ORD1053' 'ORD1054' 'ORD1055'
#  'ORD1056' 'ORD1057' 'ORD1058' 'ORD1059' 'ORD1060' 'ORD1061' 'ORD1062'
#  'ORD1063' 'ORD1064' 'ORD1065' 'ORD1066' 'ORD1067' 'ORD1068' 'ORD1069'
#  'ORD1070' 'ORD1071' 'ORD1072' 'ORD1073' 'ORD1074' 'ORD1075' 'ORD1076'
#  'ORD1077' 'ORD1078' 'ORD1079' 'ORD1080' 'ORD1081' 'ORD1082' 'ORD1083'
# ...

# %%
df_superstore.duplicated().sum()
# Out:
# 0
